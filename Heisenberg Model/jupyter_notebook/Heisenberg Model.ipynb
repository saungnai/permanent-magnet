# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
import subprocess
import sys


from config import *
from src.functions import *
from src.parallel import *

# %% [markdown]
# # Notebook to Test/Run Experiments

# %% [markdown]
# ## Color Gradient of Spin Angles in Lattice

# %%
#%run "../experiment/spin_angle_lattice.py"

# %% [markdown]
# ## Hysteresis Experiments

# %%
import time
start = time.perf_counter()

#subprocess.run(
    #[sys.executable, "-m", "experiment.Dmap_comparison"],
    #cwd=ROOT
#)
# %run "../experiment/Dmap_comparison.py"

print("Runtime =", time.perf_counter() - start)
# Out:
# Mean Hc = 2.076246603714419
# Std Hc = 0.03254205930906226
#
# Mean Hc = 1.4913800288856895
# Std Hc = 0.027127683630667247
#
# Mean Hc = 1.3080532027798326
# Std Hc = 0.007699690079607796
#
# Mean Hc = 1.0360096014282458
# Std Hc = 0.017033067055957474
#
# Mean Hc = 2.940493735981237
# Std Hc = 0.0716106927505701
#
# Mean Hc = 0.7323163097837148
# Std Hc = 0.008813568362954285
#
# Mean Hc = 0.7834189162078926
# Std Hc = 0.015095100605134434
# Runtime = 215.592277299962

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 RESULTS = ROOT / "results"
# ----> 2 HcValues1 = np.load(RESULTS / "HcValues1.npy")
#       3 HcValues2 = np.load(RESULTS / "HcValues2.npy")
#       4 HcValues3 = np.load(RESULTS / "HcValues3.npy")
#       5 HcValues4 = np.load(RESULTS / "HcValues4.npy")
#
# File ~\anaconda3\envs\permanent-magnet\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Powster\\Documents\\~ Research Project\\Permanent Magnet\\Heisenberg Model\\results\\HcValues1.npy'
